# %% [markdown]
# # Validate precipitation bias correction
#
# Plot before and after BC

# %%
import time
import xarray as xr
import dask
import numpy as np
from random import randrange
import gc
import sys
import glob
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import matplotlib.patches as patches

# sys.path.append('/glade/u/home/bkruyt/libraries')
# sys.path.append('/glade/u/home/bkruyt/libraries/st_lines')
# sys.path


sys.path.insert(1, '../2_Bias_Correct/')
import quantile_mapping # from same folder.

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import matplotlib.patches as patches

# %% [markdown]
# ### Functions

# %%
test=True
def get_data_to_match(icar_pcp, bc_grid_files):
    """get data of the output grid, cropped to the icar grid (defined by icar_pcp)"""

    t0 = time.time()
    print("\n- - - - - - - - - -   opening output grid files - - - - - - - - - - - - ")

    ### Livneh Precipitation [mm]
    # bc_grid_files = glob.glob("/glade/campaign/ral/hap/common/Livneh_met_updated/precip/livneh_unsplit_precip.2021-05-02.19[8-9]*.nc")

    print('   ',len(bc_grid_files), " output grid files " ) # the number of files (years)

    if test: # speed up for testing
        ds_out_grid    = xr.open_mfdataset(bc_grid_files[:10])
    else:
        ds_out_grid    = xr.open_mfdataset(bc_grid_files)

    latvar, lonvar     = get_latlon_vars( ds_out_grid )
    latvar_I, lonvar_I = get_latlon_vars( icar_pcp )

    # # # crop out_grid to ICAR bounds (or other way around if out grid is smaller!):
    max_lat = min( icar_pcp[latvar_I].max().values, ds_out_grid[latvar].max().values )
    min_lat = max( icar_pcp[latvar_I].min().values, ds_out_grid[latvar].min().values )

    max_lon = min( icar_pcp[lonvar_I].max().values, ds_out_grid[lonvar].max().values )
    min_lon = max( icar_pcp[lonvar_I].min().values, ds_out_grid[lonvar].min().values )

    LatIndexer, LonIndexer = latvar, lonvar #'lat', 'lon'

    ds_out_grid = ds_out_grid.sel(**{LatIndexer: slice(min_lat, max_lat ),
                            LonIndexer: slice(min_lon, max_lon)})


    # livneh_pr   = livneh["PRCP"]#.load()
    pvar_outgrid = get_pcp_var(ds_out_grid)
    da_pcp       = ds_out_grid[pvar_outgrid]

    # clean up some data; correct time dimension:
    if 'Time' in da_pcp.dims:
        da_pcp = da_pcp.rename( {'Time':'time'})
    if not ('time' in da_pcp.dims):
        print(' warning ' )

    print("   ", time.time() - t0)
    return da_pcp

# %%
noise_path  = "/glade/derecho/scratch/bkruyt/CMIP6"
NOISE_u     = xr.open_dataset(f"{noise_path}/uniform_noise_480_480.nc" )
noise_val   = 0.01


def add_noise(df, noise_val=noise_val, random=True):
    """Add uniform noise to a 2D dataset df."""

    with dask.config.set(**{'array.slicing.split_large_chunks': True}):

        u_noise = NOISE_u.uniform_noise  #.load() # 55000 x 480 x480

        # Add noise to (daily) input data:
        # to avoid taking the same noise values every time, we add a random int.
        t = len(df.time)
        if random:
            r = randrange(1000)
        else:
            r = 0
        noise_arr = noise_val * u_noise[r:(r+t) , :df.shape[1], :df.shape[2] ]
        df = xr.where( df>0, df + noise_val, noise_arr.values)

        return df

# %% [markdown]
# ### settings

# %%
###########
CMIP  = "CMIP6"
model = "MIROC-ES2L"
scen  = "ssp585"
dt    = "daily"
raw_path = f"/glade/campaign/ral/hap/bert/{CMIP}/WUS_icar_nocp_full" # ICAR on icar grid
base_in  = f"/glade/derecho/scratch/bkruyt/{CMIP}/PNW_icar_gmet"      # the output of 1_Regrid
path_out = f"/glade/campaign/ral/hap/bert/{CMIP}/PNW_icar_gmetBC"     # after Bias corr
path_out2 = f"/glade/campaign/ral/hap/bert/{CMIP}/PNW_icar_gmetBC2"     # after Bias corr
OG_obs_path = "/glade/derecho/scratch/bkruyt/gmet_daily/"
obs_path = "/glade/derecho/scratch/bkruyt/gmet_libby_daily_Tfix/"
# bc_grid_files = glob.glob("/glade/derecho/scratch/bkruyt/gmet_daily/ens_forc.LIBBY.0625*.nc")
year     = "*"

# %% [markdown]
# ### Get input data

# %%
ds_in = xr.open_mfdataset(f"{base_in}/{model}_{scen}/{dt}/icar_*_{year}.nc")

# %% [markdown]
# ### Raw data on ICAR grid (WUS wide)

# %%
ds_raw = xr.open_mfdataset(f"{raw_path}/{model}_{scen}/{dt}/icar_*_{year}.nc")#.isel(
    # lat_y=slice(ds_in.latitude.min().values, ds_in.latitude.max().values )).isel(
    # lon_x=slice(ds_in.longitude.min().values, ds_in.longitude.max().values ))

# %%
f"{path_out}/{model}_{scen}/{dt}"
# Out:
# '/glade/campaign/ral/hap/bert/CMIP6/PNW_icar_gmetBC/MIROC-ES2L_ssp585/daily'

# %%
ds_bc = xr.open_mfdataset(f"{path_out}/{model}_{scen}/{dt}/icar_*_{year}.nc")
ds_bc2 = xr.open_mfdataset(f"{path_out2}/{model}_{scen}/{dt}/icar_*_{year}.nc")

ds_bc_h = xr.open_mfdataset(f"{path_out}/{model}_hist/{dt}/icar_*_{year}.nc")
ds_bc2_h = xr.open_mfdataset(f"{path_out2}/{model}_hist/{dt}/icar_*_{year}.nc")

# %% [markdown]
# ## Precipitation plots

# %%
ds_in.Prec.sum(dim='time').plot()

# %%
ds_raw.Prec.sum(dim='time').plot()

# %% [markdown]
# ### After BC

# %%
ds_bc.Prec.sum(dim='time').plot()

# %% [markdown]
# ### Plot timeseries

# %%
a=10 ; b=10 # random point in domain
ds_in.Prec[:,a,b].plot(label="before", alpha=.5)
ds_bc.Prec[:,a,b].plot(label="after", alpha=.5)
plt.legend()
# plt.figsize((20,13))
plt.show()

# %% [markdown]
# ## Temperature plots

# %%
print(ds_in.Tmin.min().values)
ds_in.Tmin.min(dim='time').plot()
# Out:
# 234.0783

# %%
print(ds_in.Tmax.max().values)
ds_in.Tmax.max(dim='time').plot()
# Out:
# 317.3406

# %%
print(ds_bc.Tmin.min().values)
ds_bc.Tmin.min(dim='time').plot()
# Out:
# 222.73409

# %%
print(ds_bc.Tmax.max().values)
ds_bc.Tmax.max(dim='time').plot()
# Out:
# 317.14948

# %%
print(ds_bc2.Tmax.max().values)
ds_bc2.Tmax.max(dim='time').plot()
# Out:
# 316.9793

# %%
(ds_bc2.Tmax.max(dim='time') - ds_bc.Tmax.max(dim='time') ).plot()

# %% [markdown]
# ## Change signal
# -  Let’s make some summary plots,
#     -  eg mean annual values (including mean annual maximum),
#     -  change in mean annual values
#     -  and time series of mean annual values for a few regions, like the region we saw weird temperatures in and a region that looked more normal. To confirm that things look OK.

# %%
###########
CMIP  = "CMIP6"
model = "MIROC-ES2L"
# model = "CanESM5"
scen  = "ssp585"
# scen  = "ssp585"
dt    = "daily"
path_out = f"/glade/campaign/ral/hap/bert/{CMIP}/PNW_icar_gmetBC"     # after Bias corr
path_out2 = f"/glade/campaign/ral/hap/bert/{CMIP}/PNW_icar_gmetBC2"     # after Bias corr

# %%
dsP = xr.open_mfdataset(f"{path_out}/{model}_hist/{dt}/icar_*.nc")
dsF = xr.open_mfdataset(f"{path_out}/{model}_{scen}/{dt}/icar_*.nc")

dsP2 = xr.open_mfdataset(f"{path_out2}/{model}_hist/{dt}/icar_*.nc")
dsF2 = xr.open_mfdataset(f"{path_out2}/{model}_{scen}/{dt}/icar_*.nc")

# %%
P_tmax_mean = dsP.Tmax.groupby("time.year").mean()
F_tmax_mean = dsF.Tmax.groupby("time.year").mean()
print( np.nanmin(P_tmax_mean.mean(dim='year') ),  np.nanmax(P_tmax_mean.mean(dim='year') )) 
print(np.nanmin(F_tmax_mean.mean(dim='year')), np.nanmax(F_tmax_mean.mean(dim='year'))  )
# Out:
# 273.33902 289.01306
# 278.68512 293.1744

# %%
P_tmax_mean = dsP.Tmax.sel(time=slice('1970','2000')).mean(dim='time')
F_tmax_mean = dsF.Tmax.sel(time=slice('2070','2100')).mean(dim='time')
# print( np.nanmin(P_tmax_mean2 ), np.nanmax(P_tmax_mean2)) 
# print(np.nanmin(F_tmax_mean2), np.nanmax(F_tmax_mean2)  )

P_tmax_mean2 = dsP2.Tmax.sel(time=slice('1970','2000')).mean(dim='time')
F_tmax_mean2 = dsF2.Tmax.sel(time=slice('2070','2100')).mean(dim='time')
print( np.nanmin(P_tmax_mean2 ), np.nanmax(P_tmax_mean2)) 
print(np.nanmin(F_tmax_mean2), np.nanmax(F_tmax_mean2)  )
# Out:
# 273.37192 288.938
# 281.31967 295.44595

# %%
# ( F_tmax_mean.mean(dim='year')-P_tmax_mean.mean(dim='year') ).plot()
# plt.title(f"{model} {scen} change in mean annual Tmax")
# plt.show()

# %%
fig, ax= plt.subplots(1,3, figsize=(18,5))
vmin=270 ; vmax=300
imP= ax[0].pcolormesh( P_tmax_mean, cmap='turbo' ,vmin=vmin,vmax=vmax)
imF= ax[1].pcolormesh( F_tmax_mean, cmap='turbo',vmin=vmin,vmax=vmax)
imD= ax[2].pcolormesh( F_tmax_mean-P_tmax_mean ) #, cmap='RdBu', vmin=-5, vmax=+5 )

fig.subplots_adjust(right=0.91, left=0.09) # , bottom=0.1 ) #, top=1.25, bottom=-0.2 , hspace=0.001)
cbar_ax = fig.add_axes([0.03, 0.15, 0.02, 0.7])
fig.colorbar(imP, cax=cbar_ax )
cbar_ax.set_title( "K")

cbar_ax2 = fig.add_axes([0.93, 0.15, 0.02, 0.7])
fig.colorbar(imD, cax=cbar_ax2 )
cbar_ax2.set_title( "K")

ax[0].set_title(f"Past mean annual Tmax")
ax[1].set_title(f"Future mean annual Tmax")
ax[2].set_title(f"change in mean annual Tmax")
fig.suptitle(f"{model} {scen} ")
plt.show()

# %% [markdown]
# ### 1970-200 vs 2070-2100:

# %%
fig, ax= plt.subplots(1,3, figsize=(18,5))
vmin=270 ; vmax=300
imP= ax[0].pcolormesh( P_tmax_mean2, cmap='turbo', vmin=vmin,vmax=vmax)
imF= ax[1].pcolormesh( F_tmax_mean2, cmap='turbo', vmin=vmin,vmax=vmax)
imD= ax[2].pcolormesh( F_tmax_mean2-P_tmax_mean2 )

fig.subplots_adjust(right=0.91, left=0.09) # , bottom=0.1 ) #, top=1.25, bottom=-0.2 , hspace=0.001)
cbar_ax = fig.add_axes([0.03, 0.15, 0.02, 0.7])
fig.colorbar(imP, cax=cbar_ax )
cbar_ax.set_title( "K")

cbar_ax2 = fig.add_axes([0.93, 0.15, 0.02, 0.7])
fig.colorbar(imD, cax=cbar_ax2 )
cbar_ax2.set_title( "K")

ax[0].set_title(f"Past (1970-2000) mean Tmax")
ax[1].set_title(f"Future (2070-2100) mean Tmax")
ax[2].set_title(f"change in mean  Tmax")
fig.suptitle(f"{model} {scen} 1970-2000 vs 2070-2100 ")
plt.show()

# %%
(( F_tmax_mean2-P_tmax_mean2 ) - ( F_tmax_mean-P_tmax_mean )).plot()

# %%
(F_tmax_mean2-P_tmax_mean2).isel(latitude=slice(30,36)).isel(longitude=slice(30,39)).plot()

# %%
P_tmin_mean = dsP.Tmin.groupby("time.year").mean()
F_tmin_mean = dsF.Tmin.groupby("time.year").mean()

( F_tmin_mean.mean(dim='year')-P_tmin_mean.mean(dim='year') ).plot()
plt.title(f"{model} {scen} change in mean annual Tmin")
plt.show()

# %%
# the spot that had weird maxima before (Past):
dsP.Tmax.isel(latitude=33).isel(longitude=37).plot()   
dsP.Tmin.isel(latitude=33).isel(longitude=37).plot() 
plt.grid()

# %%
# the spot that had weird maxima before (Future):
dsF.Tmax.isel(latitude=33).isel(longitude=37).plot()   
dsF.Tmin.isel(latitude=33).isel(longitude=37).plot()   
plt.grid()

# %%
# previously weird spot:
P_tmax_mean.isel(latitude=33).isel(longitude=37).plot()   
F_tmax_mean.isel(latitude=33).isel(longitude=37).plot()   
P_tmin_mean.isel(latitude=33).isel(longitude=37).plot()   
F_tmin_mean.isel(latitude=33).isel(longitude=37).plot()   

# random (OK?) spot:
P_tmax_mean.isel(latitude=23).isel(longitude=27).plot(linestyle=":")   
F_tmax_mean.isel(latitude=23).isel(longitude=27).plot(linestyle=":")   
P_tmin_mean.isel(latitude=23).isel(longitude=27).plot(linestyle=":")   
F_tmin_mean.isel(latitude=23).isel(longitude=27).plot(linestyle=":")   

# # random (OK?) spot:
# P_tmax_mean.isel(latitude=43).isel(longitude=17).plot(linestyle="-.")   
# F_tmax_mean.isel(latitude=43).isel(longitude=17).plot(linestyle="-.")   
# P_tmin_mean.isel(latitude=43).isel(longitude=17).plot(linestyle="-.")   
# F_tmin_mean.isel(latitude=43).isel(longitude=17).plot(linestyle="-.")

# %% [markdown]
# ### Precip change

# %%
P_meanPCP = dsP.Prec.groupby("time.year").mean()
F_meanPCP = dsF.Prec.groupby("time.year").mean()

P_maxPCP = dsP.Prec.groupby("time.year").max()
F_maxPCP = dsF.Prec.groupby("time.year").max()

# %%
fig, ax= plt.subplots(1,3, figsize=(18,5))
vmin=0 ; vmax=10
imP= ax[0].pcolormesh( P_meanPCP.mean(dim='year'), cmap='turbo' ,vmin=vmin,vmax=vmax)
imF= ax[1].pcolormesh( F_meanPCP.mean(dim='year'), cmap='turbo',vmin=vmin,vmax=vmax)
imD= ax[2].pcolormesh( F_meanPCP.mean(dim='year')-P_meanPCP.mean(dim='year') ) #, cmap='RdBu', vmin=-5, vmax=+5 )

fig.subplots_adjust(right=0.91, left=0.09) # , bottom=0.1 ) #, top=1.25, bottom=-0.2 , hspace=0.001)
cbar_ax = fig.add_axes([0.03, 0.15, 0.02, 0.7])
fig.colorbar(imP, cax=cbar_ax )
cbar_ax.set_title( "mm")

cbar_ax2 = fig.add_axes([0.93, 0.15, 0.02, 0.7])
fig.colorbar(imD, cax=cbar_ax2 )
cbar_ax2.set_title( "mm")

ax[0].set_title(f"Past mean annual precipitation")
ax[1].set_title(f"Future mean annual precipitation")
ax[2].set_title(f"change in mean annual precipitation")
fig.suptitle(f"{model} {scen} ")
plt.show()

# %%
fig, ax= plt.subplots(1,3, figsize=(18,5))
vmin=0 ; vmax=100
imP= ax[0].pcolormesh( P_maxPCP.mean(dim='year'), cmap='turbo' ,vmin=vmin,vmax=vmax)
imF= ax[1].pcolormesh( F_maxPCP.mean(dim='year'), cmap='turbo',vmin=vmin,vmax=vmax)
imD= ax[2].pcolormesh( F_maxPCP.mean(dim='year')-P_maxPCP.mean(dim='year') ) #, cmap='RdBu', vmin=-5, vmax=+5 )

fig.subplots_adjust(right=0.91, left=0.09) # , bottom=0.1 ) #, top=1.25, bottom=-0.2 , hspace=0.001)
cbar_ax = fig.add_axes([0.03, 0.15, 0.02, 0.7])
fig.colorbar(imP, cax=cbar_ax )
cbar_ax.set_title( "mm")

cbar_ax2 = fig.add_axes([0.93, 0.15, 0.02, 0.7])
fig.colorbar(imD, cax=cbar_ax2 )
cbar_ax2.set_title( "mm")

ax[0].set_title(f"Past annual max precipitation")
ax[1].set_title(f"Future  annual max precipitation")
ax[2].set_title(f"change in  annual max precipitation")
fig.suptitle(f"{model} {scen} ")
plt.show()

# %% [markdown]
# ## Plot observations

# %%
ds_obs  = xr.open_mfdataset(f"{obs_path}/ens_forc.LIBBY.0625*.nc")
OG_obs  = xr.open_mfdataset(f"{OG_obs_path}/ens_forc.LIBBY.0625*.nc")

# %%
ds_obs.Prec.mean(dim='time').plot()

# %%
ds_obs.Prec.max(dim='time').plot()

# %%
ds_obs.Tmax.max(dim='time').plot()

# %%
OG_obs.Tmax.max(dim='time').plot()

# %%
# orginial obs
og_path = "/glade/derecho/scratch/mizukami/transfer/libby/02.gmet_bias_correction/gmet_adjusted"
ds_obs_og  = xr.open_mfdataset(f"{og_path}/ens_forc.LIBBY.0625*.nc")

# %%
print( ds_obs_og.airtemp.min().values)
ds_obs_og.airtemp.min(dim='time').plot()
# Out:
# 219.11668

# %%
print( ds_obs_og.airtemp.max().values)
ds_obs_og.airtemp.max(dim='time').plot()
# Out:
# 328.08127

# %%
ds_obs_og.airtemp.isel(latitude=slice(31,36)).isel(longitude=slice(35,39)).max(dim='time').plot()
# ds_obs_og.airtemp.isel(latitude=slice(32,35)).isel(longitude=slice(36,38)).max(dim='time').plot()

# %%
ds_obs_og.airtemp.isel(latitude=33).isel(longitude=37).plot()   # 33 lat ; 36 or 37 lon is max

# %%
ds_obs_og.airtemp.sel(time=slice(None, 'ic).max(dim='time').plot()

# %%
ds_obs_og.airtemp.sel(time=slice(None, '2015')).max(dim='time').plot()

# %%
start_year=1950 ; end_year=1950 ; dt="3hr"

files=[]
for y in range(int(start_year), int(end_year)+1) :

    if CMIP=="CMIP6":
        files.extend( glob.glob(f'{base_in}/{model}_hist/{dt}/icar_*_{y}*.nc') )
        files.extend( glob.glob(f'{base_in}/{model}_{scen_load}_2004/{dt}/icar_*_{y}*.nc') )
        files.extend( glob.glob(f'{base_in}/{model}_{scen_load}_2049/{dt}/icar_*_{y}*.nc') )

pr   =  xr.open_mfdataset( files )['precip_dt']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-77c9d14e7020> in <module>
#       6     if CMIP=="CMIP6":
#       7         files.extend( glob.glob(f'{base_in}/{model}_hist/{dt}/icar_*_{y}*.nc') )
# ----> 8         files.extend( glob.glob(f'{base_in}/{model}_{scen_load}_2004/{dt}/icar_*_{y}*.nc') )
#       9         files.extend( glob.glob(f'{base_in}/{model}_{scen_load}_2049/{dt}/icar_*_{y}*.nc') )
#      10
#
# NameError: name 'scen_load' is not defined

# %% [markdown]
# #### Get Ref data

# %%
start_year=1951 ; end_year=1952 ; dt="3hr"

files=[]
for y in range(int(start_year), int(end_year)+1) :

    if CMIP=="CMIP6":
        files.extend( glob.glob(f'{base_in}/{model}_hist/{dt}/icar_*_{y}*.nc') )
        files.extend( glob.glob(f'{base_in}/{model}_{scen_load}_2004/{dt}/icar_*_{y}*.nc') )
        files.extend( glob.glob(f'{base_in}/{model}_{scen_load}_2049/{dt}/icar_*_{y}*.nc') )

Ref_3h   =  xr.open_mfdataset( files )['precip_dt']

# %%
# plt.pcolormesh( pr.sum(dim='time') )

# %% [markdown]
# #### Get  Obs data

# %%
livneh_pr = get_livneh(icar_1file=pr.isel(time=0))
dsObs     = livneh_pr.load()
# Out:
# - - - - - - - - - -   opening livneh files - - - - - - - - - - - -
#    ! TEST :  10  Livneh precipiation files(years)
#     2.670647382736206

# %%
## make daily from input and ref:
tdelta_int=3
if tdelta_int<24:
    print("   making daily precip")
    daily = pr.resample(time='1D').sum(dim='time').load()
    dsRef = Ref_3h.resample(time='1D').sum(dim='time').load()
else:
    daily = pr.load()
# Out:
#    making daily precip

# %%
## add noise
daily_n = add_noise(daily, noise_val=noise_val, random=True)
dsRef_n = add_noise(dsRef, noise_val=noise_val, random=True)

# %%
# reduce array shape:
a=150; b=200
daily_n = daily_n.isel(lat=slice(a,b)).isel(lon=slice(a,b))
dsRef_n = dsRef_n.isel(lat=slice(a,b)).isel(lon=slice(a,b))
dsObs   = dsObs.isel(lat=slice(a,b)).isel(lon=slice(a,b))


daily = daily.isel(lat=slice(a,b)).isel(lon=slice(a,b))
pr    = pr.isel(lat=slice(a,b)).isel(lon=slice(a,b))

print( daily_n.shape, dsRef_n.shape, dsObs.shape )
plt.pcolormesh( pr.sum(dim='time') )
# Out:
# (365, 50, 50) (731, 50, 50) (3652, 50, 50)

# %%
np.count_nonzero( daily.values<0)
# Out:
# 0

# %% [markdown]
# ## Bias Correct
#
# NB: (very small) negative values are introduced by the bc procedure when setting extrapolate='1to1'. (This does not happen when dsRef=None. ). To prevent this we set extrapolate to max.

# %%
print(daily_n.shape, dsRef_n.shape, dsObs.shape)

bc_daily = quantile_mapping.quantile_mapping_by_group(
    # def quantile_mapping_by_group(input_data, ref_data, data_to_match, (ref should exclude 5y input)
    daily_n,  dsRef_n, dsObs, 
    # daily_n,  None, dsObs, 
    grouper='time.month', detrend=False,  use_ref_data=True,# use_ref_data is not used! set ref_data=None to exclude ref data!
    extrapolate="1to1", n_endpoints=50
    )

print(f"\n   {np.count_nonzero(daily<0)} negative values before BC")
print(f"   {np.nanmin(daily)} min value before BC")
print(f"   {np.count_nonzero(bc_daily<0)} negative values after BC")
print(f"   {np.nanmin(bc_daily)} min value after BC")
# Out:
# (365, 50, 50) (731, 50, 50) (3652, 50, 50)
# kwargs: {'alpha': 0.4, 'beta': 0.4, 'extrapolate': '1to1', 'n_endpoints': 50}
# putting the trend back
# kwargs: {'alpha': 0.4, 'beta': 0.4, 'extrapolate': '1to1', 'n_endpoints': 50}
# putting the trend back
# kwargs: {'alpha': 0.4, 'beta': 0.4, 'extrapolate': '1to1', 'n_endpoints': 50}
# putting the trend back
# kwargs: {'alpha': 0.4, 'beta': 0.4, 'extrapolate': '1to1', 'n_endpoints': 50}
# putting the trend back
# kwargs: {'alpha': 0.4, 'beta': 0.4, 'extrapolate': '1to1', 'n_endpoints': 50}
# putting the trend back
# kwargs: {'alpha': 0.4, 'beta': 0.4, 'extrapolate': '1to1', 'n_endpoints': 50}
# putting the trend back
# kwargs: {'alpha': 0.4, 'beta': 0.4, 'extrapolate': '1to1', 'n_endpoints': 50}
# putting the trend back
# kwargs: {'alpha': 0.4, 'beta': 0.4, 'extrapolate': '1to1', 'n_endpoints': 50}
# putting the trend back
# kwargs: {'alpha': 0.4, 'beta': 0.4, 'extrapolate': '1to1', 'n_endpoints': 50}
# putting the trend back
# ...

# %% [markdown]
# ### Reapply to daily:

# %%
correction = bc_daily.values / daily_n.values
# Create a mask for elements where daily sum is zero and bc_daily is positive
# mask = (daily2.values == 0) & (bc_daily.values > 0)
mask = np.logical_and( (daily.values == 0) , (bc_daily.values > 0) )

daily_crtd = daily * correction

daily_corr_final =  np.where( mask, bc_daily, daily_crtd )
# daily_corr_final =  daily_crtd.where( ~mask, bc_daily)  # equivalent xr.where statement

# %%
np.count_nonzero(bc_daily<0)
# np.count_nonzero(daily2<0)
# np.count_nonzero(correction<0)
np.count_nonzero(daily_crtd.values<0)
np.count_nonzero(daily_corr_final<0)
# Out:
# 0

# %%
# t0=-50 ; t1=-1 ; y=200; x=200
t0=-50 ; t1=-1 ; y=20; x=20   # when cropped
plt.figure(figsize=(15,8))

plt.plot(daily.time[t0:t1], daily[t0:t1,y,x], label='daily org')
plt.plot(bc_daily.time[t0:t1], bc_daily[t0:t1,y,x], label='bc daily')
plt.plot(daily_crtd.time[t0:t1], daily_crtd[t0:t1,y,x], label='daily_crtd', linestyle="--")
plt.plot(daily_crtd.time[t0:t1], daily_corr_final[t0:t1,y,x], label='daily_corr_final', linestyle="-.")

plt.plot(bc_daily.time[t0:t1], mask[t0:t1,y,x]*10, label='mask', color='grey', linestyle=":")

# plt.plot(bc_daily.time[t0:t1], correction[t0:t1,y,x], label='correction', color='red', linestyle=":")

# plt.ylim(0,.2) # zoom in to see the effect of np.where( mask, bc_daily, daily_crtd )

plt.legend()
# plt.xlim(bc_daily.time.isel(time=0), bc_daily.time.isel(time=80))
plt.grid()

# %%
# plt.plot(bc_daily.time[t0:t1], mask[t0:t1,y,x]*10, label='mask', color='grey', linestyle=":")

# plt.plot(bc_daily.time[t0:t1], correction[t0:t1,y,x], label='correction', color='red', linestyle=":")

plt.plot( correction[:,y,x], label='correction', color='red', linestyle=":")

# %% [markdown]
# ### Reapply to 3hr:

# %%
print("      pr.shape:",pr.shape)
print("      pr == 0 :",np.sum(pr.values==0))
print("   applying correction to ",tdelta_int,"-hourly data")
# Out:
#       pr.shape: (2920, 378, 403)
#       pr == 0 : 289478208
#    applying correction to  3 -hourly data

# %%
correction = np.where(bc_daily.values>=0, bc_daily.values / daily_n.values, 0 ) # 
print(f"      correction min/max:{np.nanmin(correction)} {np.nanmax(correction)} ")
# Out:
#       correction min/max:-926812.75 20740.25390625

# %%
# Calculate the correction array
correction = bc_daily.values / daily_n.values
# repeat for nr of timesteps per day:
correction =  np.repeat(correction, (24 / tdelta_int), axis=0)

# Create a mask for elements where daily sum is zero and bc_daily is positive
mask = (daily.values == 0) & (bc_daily.values > 0)
# mask = np.logical_and( (daily2.values == 0) , (bc_daily.values > 0) )
print( f"condition met :{np.count_nonzero( mask)} times (in daily mask)" )

# mask = mask.interp(time=pr.time)
mask2 = np.repeat(mask, (24 / tdelta_int), axis=0)
print( f"condition met :{np.count_nonzero( mask2)} times (in 3h mask)" )

print(f"      mask shape: {mask.shape}")
print(f"      mask2 shape: {mask2.shape}")
print(f"      correction shape: {correction.shape} ") # \n
print(f"      correction min/max:{np.nanmin(correction)} {np.nanmax(correction)} ")
# Out:
# condition met :2555266 times (in daily mask)
# condition met :20442128 times (in 3h mask)
#       mask shape: (365, 378, 403)
#       mask2 shape: (2920, 378, 403)
#       correction shape: (2920, 378, 403)
#       correction min/max:-926812.75 20740.25390625

# %%
### bc introduces negative values....

# %%
print(
    np.count_nonzero( daily.values<0), '\n',
    np.count_nonzero( daily_n.values<0), '\n',
    np.count_nonzero( bc_daily.values<0), '\n',
    np.count_nonzero( correction<0), '\n',
    np.count_nonzero( dsRef_n<0), '\n',
    np.count_nonzero( dsObs<0), '\n',

)

print(np.nanmin(bc_daily), np.nanmin(correction))
# Out:
# 0
#  0
#  16089
#  16089
#  0
#  0
#
# -0.0055648508 -3688.3735

# %% [markdown]
# #### interpolate the daily bc to 3hr
#
# 1D to test

# %%
y=100; x=100
bc_tdelta_1D =  bc_daily[:,y,x].interp(time=pr.time, method='zero') /(24 / tdelta_int) 
# bc_tdelta =  np.repeat(bc_daily.values, (24 / tdelta_int), axis=0) / (24 / tdelta_int)

# bc_tdelta = np.interp(pr.time.values, bc_daily.time.values, bc_daily.values) # to deep?

# print(f"   bc_tdelta shape: {bc_tdelta.shape}")
print( bc_tdelta_1D.time )
# Out:
# <xarray.DataArray 'time' (time: 2920)>
# array(['1950-01-01T00:00:00.000000000', '1950-01-01T03:00:00.000000000',
#        '1950-01-01T06:00:00.000000000', ..., '1950-12-31T15:00:00.000000000',
#        '1950-12-31T18:00:00.000000000', '1950-12-31T21:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#     lat      float64 35.53
#     lon      float64 -118.3
#   * time     (time) datetime64[ns] 1950-01-01 ... 1950-12-31T21:00:00

# %%
plt.figure(figsize=(15,8))
# plt.plot(bc_daily.time, bc_daily[:,y,x], label='bc daily')
# plt.plot(bc_tdelta.time, bc_tdelta[:,y,x], label='bc_tdelta', linestyle="-.")
plt.plot(bc_daily.time, bc_daily[:,y,x], label='bc daily')
plt.plot(bc_tdelta_1D.time, bc_tdelta_1D, label='bc_tdelta', linestyle="-.")

plt.scatter(bc_daily.time, bc_daily[:,y,x], label='bc daily')
plt.scatter(bc_tdelta_1D.time, bc_tdelta_1D, label='bc_tdelta', linestyle="-.")
plt.scatter(bc_daily.time, bc_tdelta_1D.resample(time='D').sum(), 
            label='bc_tdelta day sum',marker='x')

# plt.plot(bc_tdelta[:t1,y,x], label='bc_tdelta', linestyle=":")
# plt.plot( mask[:,y,x]*10, label='mask', color='grey', linestyle=":")
# plt.plot( mask2[:,y,x]*10, label='mask2', color='black', linestyle=":")
# plt.plot( correction[:,y,x], label='correction', color='red', linestyle=":")
plt.xlim(bc_daily.time[0], bc_daily.time[13])

plt.legend()
# plt.xlim(bc_daily.time.isel(time=0), bc_daily.time.isel(time=80))
plt.grid()

# %% [markdown]
# ### interp 3D

# %%
bc_tdelta =  bc_daily.interp(time=pr.time, method='zero') /(24 / tdelta_int)  # time consuming in 3D!

pr3  = pr.copy()

pr3 *= correction

pr4 = pr3.where(~mask2, bc_tdelta )

# da_pcp = pr.where(~mask, bc_tdelta/(24 / tdelta_int))
# da_pcp = da_pcp.where(~mask, bc_tdelta )

pr5 =  np.where( mask2, bc_tdelta, pr3 )

# %%
## NANS:
# np.count_nonzero(pr.isnull()), np.count_nonzero(pr3.isnull()), np.count_nonzero(pr4.isnull())

## neg vals:
np.count_nonzero(pr.values<0), np.count_nonzero(pr3.values<0), np.count_nonzero(pr4.values<0)
# Out:
# (0, 8351, 8351)

# %%
# print( np.where( pr3 <0) )
print( np.where( pr3 ==np.nanmin(pr3) ) )

# pr3[480,334,137].values, np.nanmin(pr3)
# Out:
# (array([1392]), array([360]), array([106]))

# %%
fig,ax0=plt.subplots()
im = ax0.pcolormesh(pr.lon, pr.lat, pr3.isel(time=480),cmap='RdBu' , vmin=-.000000001, vmax=.000000001)
fig.colorbar(im, ax=ax0)
# Out:
# /glade/work/yifanc/anaconda3/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.

# %%
plt.pcolormesh( pr3.isel(time=480),cmap='RdBu' , vmin=np.nanmin(pr3), vmax=-np.nanmin(pr3))
plt.ylim(300,350)
plt.xlim(100,150)

# fig,ax0=plt.subplots()
# im = ax0.pcolormesh(pr.lon, pr.lat, pr3.isel(time=480),cmap='RdBu' , vmin=-.00001, vmax=.00001)
# fig.colorbar(im, ax=ax0)
# Out:
# (100.0, 150.0)

# %%
# t1=-1 ; y=31; x=45
t1=100 ; y=100; x=100
plt.figure(figsize=(15,8))
plt.plot(pr4[:t1,y,x], label='bc')
# plt.plot(pr4.time[:t1], pr4[:t1,y,x], label='bc')
plt.plot(pr3[:t1,y,x], label='bc_1')
plt.plot(pr[:t1,y,x], label='org', linestyle="-.")
plt.plot(bc_tdelta[:t1,y,x], label='bc_tdelta', linestyle=":")
plt.plot(mask2[:t1,y,x], label='mask', color='grey', linestyle=":")
plt.grid()
plt.legend(fontsize=15)

# %%
plt.plot(mask[:t1,y,x], label='mask', color='grey', linestyle=":")

# %%
# plt.pcolormesh( pr2.isel(time=-1))
plt.pcolormesh( pr2.sum(dim='time') )

# %%
    # # # Apply correction to (all) values
    # pr *= correction

    # for t in range( pr.shape[0]):
    #     # where mask, retrun bc_tdelta (syntax: Returns elements from ‘DataArray’, where ‘cond’ is True, otherwise fill in ‘other’. )
    #     # print(pr[t].shape, mask[t].shape, bc_tdelta[t].shape )
    #     try:
    #         pr[t] = pr[t].where(~mask[t], bc_tdelta[t])
    #     except:
    #         print(f"   pr.shape: {pr.shape} ")
    #         print(f"   mask.shape: {mask.shape} ")
    #         print(f"   bc_tdelta.shape: {bc_tdelta.shape} ")
